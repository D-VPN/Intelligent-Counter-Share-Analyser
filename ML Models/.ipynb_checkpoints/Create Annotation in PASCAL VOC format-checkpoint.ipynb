# %%
import xml.etree.ElementTree as xm
import os
import pandas as pd
import matplotlib.pyplot as plt
import uuid
# %matplotlib inline

# %%
def Generate(filename):
    root = xm.Element("root")
    m1 = gfg.Element("mobile") 
    root.append (m1) 
    tree = xm.ElementTree(root)
    with open(filename,"wb") as files:
        tree.write(files)

if __name__ == "__main__":
    Generate("Catalogue.xml")

# %%
shelf_images = ".\Shelf Images\images"
product_images = ".\Shelf Images\ProductImages"
anotation_ath = '.\Shelf Images\annotations'

# %%
for filename in os.listdir(shelf_images):
    print(filename)
# Out:
# C1_P01_N1_S2_1.JPG
# C1_P01_N1_S2_2.JPG
# C1_P01_N1_S3_1.JPG
# C1_P01_N1_S3_2.JPG
# C1_P01_N1_S5_1.JPG
# C1_P01_N2_S2_1.JPG
# C1_P01_N2_S3_1.JPG
# C1_P01_N2_S4_1.JPG
# C1_P01_N3_S2_1.JPG
# C1_P01_N3_S3_1.JPG
# C1_P01_N4_S2_1.JPG
# C1_P02_N1_S2_1.JPG
# C1_P02_N1_S3_1.JPG
# C1_P02_N1_S4_1.JPG
# C1_P02_N1_S5_1.JPG
# C1_P02_N2_S2_1.JPG
# C1_P02_N2_S3_1.JPG
# C1_P02_N2_S4_1.JPG
# C1_P02_N3_S2_1.JPG
# C1_P02_N3_S3_1.JPG
# C1_P02_N4_S2_1.JPG
# C1_P03_N1_S2_1.JPG
# C1_P03_N1_S2_2.JPG
# C1_P03_N1_S3_1.JPG
# C1_P03_N1_S3_2.JPG
# C1_P03_N1_S4_1.JPG
# C1_P03_N1_S4_2.JPG
# C1_P03_N2_S2_1.JPG
# C1_P03_N2_S3_1.JPG
# C1_P03_N2_S3_2.JPG
# C1_P03_N3_S2_1.JPG
# C1_P04_N1_S3_1.JPG
# C1_P04_N1_S3_2.JPG
# C1_P04_N1_S4_1.JPG
# C1_P04_N1_S5_1.JPG
# C1_P04_N1_S5_2.JPG
# C1_P04_N2_S3_1.JPG
# C1_P04_N2_S4_1.JPG
# C1_P04_N3_S2_1.JPG
# C1_P04_N3_S3_1.JPG
# C1_P04_N4_S2_1.JPG
# C1_P05_N1_S3_1.JPG
# C1_P05_N1_S3_2.JPG
# C1_P05_N1_S4_1.JPG
# C1_P05_N1_S4_2.JPG
# C1_P05_N1_S4_3.JPG
# C1_P05_N1_S5_1.JPG
# C1_P05_N2_S3_1.JPG
# C1_P05_N2_S4_1.JPG
# C1_P05_N2_S4_2.JPG
# C1_P05_N3_S3_1.JPG
# C1_P05_N3_S4_1.JPG
# C1_P05_N4_S3_1.JPG
# C1_P06_N1_S3_1.JPG
# C1_P06_N1_S3_2.JPG
# C1_P06_N1_S4_1.JPG
# C1_P06_N1_S4_2.JPG
# C1_P06_N1_S5_1.JPG
# C1_P06_N2_S3_1.JPG
# C1_P06_N2_S3_2.JPG
# C1_P06_N2_S3_3.JPG
# C1_P06_N3_S3_1.JPG
# C1_P06_N3_S3_2.JPG
# C1_P07_N1_S3_1.JPG
# C1_P07_N1_S3_2.JPG
# C4_P03_N2_S3_2.JPG
# C4_P03_N2_S4_1.JPG
# C4_P03_N3_S3_1.JPG
# C4_P03_N3_S3_2.JPG
# C4_P04_N1_S2_1.JPG
# C4_P04_N1_S3_1.JPG
# C4_P04_N1_S4_1.JPG
# C4_P04_N1_S5_1.JPG
# C4_P04_N2_S2_1.JPG
# C4_P04_N2_S3_1.JPG
# C4_P04_N2_S4_1.JPG
# C4_P04_N3_S3_1.JPG
# C4_P04_N4_S2_1.JPG
# C4_P04_N5_S2_1.JPG
# C4_P05_N1_S2_1.JPG
# C4_P05_N1_S3_1.JPG
# C4_P05_N1_S4_1.JPG
# C4_P05_N1_S5_1.JPG
# C4_P05_N2_S2_1.JPG
# C4_P05_N2_S3_1.JPG
# C4_P05_N2_S4_1.JPG
# C4_P05_N3_S2_1.JPG
# C4_P05_N3_S3_1.JPG
# C4_P05_N4_S2_1.JPG
# C4_P05_N5_S2_1.JPG
# C4_P06_N1_S3_1.JPG
# C4_P06_N1_S4_1.JPG
# C4_P06_N2_S3_1.JPG
# C4_P06_N4_S3_1.JPG
# C4_P07_N1_S3_1.JPG
# C4_P07_N1_S3_2.JPG
# C4_P07_N1_S4_1.JPG
# C4_P07_N1_S4_2.JPG
# C4_P07_N1_S5_1.JPG
# C4_P07_N2_S3_1.JPG
# C4_P07_N2_S3_2.JPG
# C4_P07_N2_S4_1.JPG
# C4_P07_N3_S3_1.JPG
# C4_P07_N3_S3_2.JPG
# C4_P08_N1_S2_1.JPG
# C4_P08_N1_S3_1.JPG
# C4_P08_N1_S4_1.JPG
# C4_P08_N1_S5_1.JPG
# C4_P08_N1_S5_2.JPG
# C4_P08_N2_S2_1.JPG
# C4_P08_N2_S3_1.JPG
# C4_P08_N2_S3_2.JPG
# C4_P08_N2_S4_1.JPG
# C4_P08_N3_S3_1.JPG
# C4_P08_N3_S3_2.JPG
# Thumbs.db

# %%
jpg_files = [f for f in os.listdir(f'{shelf_images}') if f.endswith('JPG')]

# %%
photos_df = pd.DataFrame([[f, f[:6], f[7:14]] for f in jpg_files], 
                         columns=['file', 'shelf_id', 'planogram_id'])
photos_df.head()
# Out:
#                  file shelf_id planogram_id
# 0  C1_P01_N1_S2_1.JPG   C1_P01      N1_S2_1
# 1  C1_P01_N1_S2_2.JPG   C1_P01      N1_S2_2
# 2  C1_P01_N1_S3_1.JPG   C1_P01      N1_S3_1
# 3  C1_P01_N1_S3_2.JPG   C1_P01      N1_S3_2
# 4  C1_P01_N1_S5_1.JPG   C1_P01      N1_S5_1

# %%
products_df = pd.DataFrame(
    [[f[:18], f[:6], f[7:14], i] 
     for i in range(1,11) 
     for f in os.listdir(f'{product_images}\\{i}')],
    columns=['file', 'shelf_id', 'planogram_id', 
             'category'])
# convert from width height to xmax, ymax
# products_df['xmax'] = products_df['xmin'] + products_df['w']
# products_df['ymax'] = products_df['ymin'] + products_df['h']
products_df.head()
# Out:
#           file shelf_id planogram_id  category
# 0    B1_N1.jpg   B1_N1.           pg         1
# 1   B1_N10.jpg   B1_N10          jpg         1
# 2  B1_N100.jpg   B1_N10         .jpg         1
# 3  B1_N101.jpg   B1_N10         .jpg         1
# 4  B1_N102.jpg   B1_N10         .jpg         1

# %%
os.listdir('.\Shelf Images\ProductImages\\1')
# Out:
# ['B1_N1.jpg',
#  'B1_N10.jpg',
#  'B1_N100.jpg',
#  'B1_N101.jpg',
#  'B1_N102.jpg',
#  'B1_N103.jpg',
#  'B1_N104.jpg',
#  'B1_N105.jpg',
#  'B1_N106.jpg',
#  'B1_N107.jpg',
#  'B1_N108.jpg',
#  'B1_N109.jpg',
#  'B1_N11.jpg',
#  'B1_N110.jpg',
#  'B1_N111.jpg',
#  'B1_N112.jpg',
#  'B1_N113.jpg',
#  'B1_N114.jpg',
#  'B1_N115.jpg',
#  'B1_N116.jpg',
#  'B1_N117.jpg',
#  'B1_N118.jpg',
#  'B1_N119.jpg',
#  'B1_N12.jpg',
#  'B1_N120.jpg',
#  'B1_N121.jpg',
#  'B1_N122.jpg',
#  'B1_N123.jpg',
#  'B1_N124.jpg',
#  'B1_N125.jpg',
#  'B1_N126.jpg',
#  'B1_N127.jpg',
#  'B1_N128.jpg',
#  'B1_N129.jpg',
#  'B1_N13.jpg',
#  'B1_N130.jpg',
#  'B1_N131.jpg',
#  'B1_N132.jpg',
#  'B1_N133.jpg',
#  'B1_N134.jpg',
#  'B1_N135.jpg',
#  'B1_N136.jpg',
#  'B1_N137.jpg',
#  'B1_N138.jpg',
#  'B1_N139.jpg',
#  'B1_N14.jpg',
#  'B1_N140.jpg',
#  'B1_N141.jpg',
#  'B1_N142.jpg',
#  'B1_N143.jpg',
#  'B1_N144.jpg',
#  'B1_N145.jpg',
#  'B1_N146.jpg',
#  'B1_N147.jpg',
#  'B1_N148.jpg',
#  'B1_N149.jpg',
#  'B1_N15.jpg',
#  'B1_N150.jpg',
#  'B1_N151.jpg',
#  'B1_N152.jpg',
#  'B1_N153.jpg',
#  'B1_N154.jpg',
#  'B1_N155.jpg',
#  'B1_N156.jpg',
#  'B1_N157.jpg',
#  'B1_N158.jpg',
#  'B1_N159.jpg',
#  'B1_N16.jpg',
#  'B1_N160.jpg',
#  'B1_N161.jpg',
#  'B1_N162.jpg',
#  'B1_N163.jpg',
#  'B1_N164.jpg',
#  'B1_N165.jpg',
#  'B1_N166.jpg',
#  'B1_N167.jpg',
#  'B1_N168.jpg',
#  'B1_N169.jpg',
#  'B1_N17.jpg',
#  'B1_N170.jpg',
#  'B1_N171.jpg',
#  'B1_N172.jpg',
#  'B1_N173.jpg',
#  'B1_N174.jpg',
#  'B1_N175.jpg',
#  'B1_N176.jpg',
#  'B1_N177.jpg',
#  'B1_N178.jpg',
#  'B1_N179.jpg',
#  'B1_N18.jpg',
#  'B1_N180.jpg',
#  'B1_N181.jpg',
#  'B1_N182.jpg',
#  'B1_N183.jpg',
#  'B1_N184.jpg',
#  'B1_N185.jpg',
#  'B1_N186.jpg',
#  'B1_N187.jpg',
#  'B1_N188.jpg',
#  'B1_N189.jpg',
#  'B1_N19.jpg',
#  'B1_N190.jpg',
#  'B1_N191.jpg',
#  'B1_N192.jpg',
#  'B1_N193.jpg',
#  'B1_N194.jpg',
#  'B1_N195.jpg',
#  'B1_N196.jpg',
#  'B1_N197.jpg',
#  'B1_N198.jpg',
#  'B1_N199.jpg',
#  'B1_N2.jpg',
#  'B1_N20.jpg',
#  'B1_N200.jpg',
#  'B1_N201.jpg',
#  'B1_N202.jpg',
#  'B1_N203.jpg',
#  'B1_N204.jpg',
#  'B1_N205.jpg',
#  'B1_N206.jpg',
#  'B1_N207.jpg',
#  'B1_N208.jpg',
#  'B1_N209.jpg',
#  'B1_N21.jpg',
#  'B1_N210.jpg',
#  'B1_N211.jpg',
#  'B1_N212.jpg',
#  'B1_N213.jpg',
#  'B1_N214.jpg',
#  'B1_N215.jpg',
#  'B1_N216.jpg',
#  'B1_N217.jpg',
#  'B1_N218.jpg',
#  'B1_N219.jpg',
#  'B1_N22.jpg',
#  'B1_N220.jpg',
#  'B1_N221.jpg',
#  'B1_N222.jpg',
#  'B1_N223.jpg',
#  'B1_N224.jpg',
#  'B1_N225.jpg',
#  'B1_N226.jpg',
#  'B1_N227.jpg',
#  'B1_N228.jpg',
#  'B1_N229.jpg',
#  'B1_N23.jpg',
#  'B1_N230.jpg',
#  'B1_N231.jpg',
#  'B1_N232.jpg',
#  'B1_N233.jpg',
#  'B1_N234.jpg',
#  'B1_N235.jpg',
#  'B1_N236.jpg',
#  'B1_N237.jpg',
#  'B1_N238.jpg',
#  'B1_N239.jpg',
#  'B1_N24.jpg',
#  'B1_N240.jpg',
#  'B1_N241.jpg',
#  'B1_N242.jpg',
#  'B1_N243.jpg',
#  'B1_N244.jpg',
#  'B1_N245.jpg',
#  'B1_N246.jpg',
#  'B1_N247.jpg',
#  'B1_N248.jpg',
#  'B1_N249.jpg',
#  'B1_N25.jpg',
#  'B1_N250.jpg',
#  'B1_N251.jpg',
#  'B1_N252.jpg',
#  'B1_N253.jpg',
#  'B1_N254.jpg',
#  'B1_N255.jpg',
#  'B1_N256.jpg',
#  'B1_N257.jpg',
#  'B1_N258.jpg',
#  'B1_N259.jpg',
#  'B1_N26.jpg',
#  'B1_N260.jpg',
#  'B1_N261.jpg',
#  'B1_N262.jpg',
#  'B1_N263.jpg',
#  'B1_N264.jpg',
#  'B1_N265.jpg',
#  'B1_N266.jpg',
#  'B1_N267.jpg',
#  'B1_N268.jpg',
#  'B1_N269.jpg',
#  'B1_N27.jpg',
#  'B1_N270.jpg',
#  'B1_N271.jpg',
#  'B1_N272.jpg',
#  'B1_N273.jpg',
#  'B1_N274.jpg',
#  'B1_N275.jpg',
#  'B1_N276.jpg',
#  'B1_N277.jpg',
#  'B1_N278.jpg',
#  'B1_N279.jpg',
#  'B1_N28.jpg',
#  'B1_N280.jpg',
#  'B1_N281.jpg',
#  'B1_N282.jpg',
#  'B1_N283.jpg',
#  'B1_N284.jpg',
#  'B1_N285.jpg',
#  'B1_N286.jpg',
#  'B1_N287.jpg',
#  'B1_N288.jpg',
#  'B1_N289.jpg',
#  'B1_N29.jpg',
#  'B1_N290.jpg',
#  'B1_N291.jpg',
#  'B1_N292.jpg',
#  'B1_N293.jpg',
#  'B1_N294.jpg',
#  'B1_N295.jpg',
#  'B1_N296.jpg',
#  'B1_N297.jpg',
#  'B1_N298.jpg',
#  'B1_N299.jpg',
#  'B1_N3.jpg',
#  'B1_N30.jpg',
#  'B1_N300.jpg',
#  'B1_N301.jpg',
#  'B1_N302.jpg',
#  'B1_N303.jpg',
#  'B1_N304.jpg',
#  'B1_N305.jpg',
#  'B1_N306.jpg',
#  'B1_N307.jpg',
#  'B1_N308.jpg',
#  'B1_N309.jpg',
#  'B1_N31.jpg',
#  'B1_N310.jpg',
#  'B1_N311.jpg',
#  'B1_N312.jpg',
#  'B1_N313.jpg',
#  'B1_N314.jpg',
#  'B1_N315.jpg',
#  'B1_N316.jpg',
#  'B1_N317.jpg',
#  'B1_N318.jpg',
#  'B1_N319.jpg',
#  'B1_N32.jpg',
#  'B1_N320.jpg',
#  'B1_N321.jpg',
#  'B1_N322.jpg',
#  'B1_N323.jpg',
#  'B1_N324.jpg',
#  'B1_N325.jpg',
#  'B1_N326.jpg',
#  'B1_N327.jpg',
#  'B1_N328.jpg',
#  'B1_N329.jpg',
#  'B1_N33.jpg',
#  'B1_N330.jpg',
#  'B1_N331.jpg',
#  'B1_N332.jpg',
#  'B1_N333.jpg',
#  'B1_N334.jpg',
#  'B1_N335.jpg',
#  'B1_N34.jpg',
#  'B1_N35.jpg',
#  'B1_N36.jpg',
#  'B1_N37.jpg',
#  'B1_N38.jpg',
#  'B1_N39.jpg',
#  'B1_N4.jpg',
#  'B1_N40.jpg',
#  'B1_N41.jpg',
#  'B1_N42.jpg',
#  'B1_N43.jpg',
#  'B1_N44.jpg',
#  'B1_N45.jpg',
#  'B1_N46.jpg',
#  'B1_N47.jpg',
#  'B1_N48.jpg',
#  'B1_N49.jpg',
#  'B1_N5.jpg',
#  'B1_N50.jpg',
#  'B1_N51.jpg',
#  'B1_N52.jpg',
#  'B1_N53.jpg',
#  'B1_N54.jpg',
#  'B1_N55.jpg',
#  'B1_N56.jpg',
#  'B1_N57.jpg',
#  'B1_N58.jpg',
#  'B1_N59.jpg',
#  'B1_N6.jpg',
#  'B1_N60.jpg',
#  'B1_N61.jpg',
#  'B1_N62.jpg',
#  'B1_N63.jpg',
#  'B1_N64.jpg',
#  'B1_N65.jpg',
#  'B1_N66.jpg',
#  'B1_N67.jpg',
#  'B1_N68.jpg',
#  'B1_N69.jpg',
#  'B1_N7.jpg',
#  'B1_N70.jpg',
#  'B1_N71.jpg',
#  'B1_N72.jpg',
#  'B1_N73.jpg',
#  'B1_N74.jpg',
#  'B1_N75.jpg',
#  'B1_N76.jpg',
#  'B1_N77.jpg',
#  'B1_N78.jpg',
#  'B1_N79.jpg',
#  'B1_N8.jpg',
#  'B1_N80.jpg',
#  'B1_N81.jpg',
#  'B1_N82.jpg',
#  'B1_N83.jpg',
#  'B1_N84.jpg',
#  'B1_N85.jpg',
#  'B1_N86.jpg',
#  'B1_N87.jpg',
#  'B1_N88.jpg',
#  'B1_N89.jpg',
#  'B1_N9.jpg',
#  'B1_N90.jpg',
#  'B1_N91.jpg',
#  'B1_N92.jpg',
#  'B1_N93.jpg',
#  'B1_N94.jpg',
#  'B1_N95.jpg',
#  'B1_N96.jpg',
#  'B1_N97.jpg',
#  'B1_N98.jpg',
#  'B1_N99.jpg',
#  'Thumbs.db']

# %%
df = pd.read_csv('./Shelf Images/annotations/annotations.csv',names = ['filename','x','y','w','h','category'])

# %%
df.head()
# Out:
#              filename     x     y     w     h  category
# 0  C1_P01_N1_S2_1.JPG  1008  1552  1260  1928         0
# 1  C1_P01_N1_S2_1.JPG  1028   928  1280  1304         0
# 2  C1_P01_N1_S2_1.JPG    24   872   268  1264         0
# 3  C1_P01_N1_S2_1.JPG   280  1568   532  1944         0
# 4  C1_P01_N1_S2_1.JPG   292   872   544  1248         0

# %%
df.shape
# Out:
# (13184, 6)

# %%
for i in range(len(df)):
    GenerateXML(df.iloc[i,0][:-4]+str(uuid.uuid1()),df.iloc[i,1],df.iloc[i,2],df.iloc[i,3],df.iloc[i,4],df.iloc[i,5])

# %%
def GenerateXML(filename,count,x,y,w,h):
    path = './Shelf Images/annotations';
    annotation = xm.Element("annotation")
    folder = xm.Element("folder")
    annotation.append(folder)
    folder.text = "images"
    fn = xm.Element("filename")
    annotation.append(fn)
    fn.text = filename
    source = xm.Element("source")
    annotation.append(source)
    db = xm.SubElement(source,"database")
    db.text ="Unknown"
    size = xm.Element("size")
    annotation.append(size)
    width = xm.SubElement(size,"width")
    width.text = "275"
    height = xm.SubElement(size,"height")
    height.text = "183"
    depth = xm.SubElement(size,"depth")
    depth.text = "3"
    segmented = xm.Element("segmented")
    annotation.append(segmented)
    segmented.text = "0"
    
    
    for i in range(1):
        obj = xm.Element('object')
        annotation.append(obj)
        pose = xm.SubElement(obj,"pose")
        pose.text = "Unspecified"
        
        truncated = xm.SubElement(obj,"truncated")
        truncated.text = "0"
        
        difficult = xm.SubElement(obj,"difficult")
        difficult.text = "0"
        
        bndbox = xm.SubElement(obj,"bndbox")
        xmin = xm.SubElement(bndbox,"xmin")
        xmin.text = str(x[i])
        ymin = xm.SubElement(bndbox,"ymin")
        ymin.text = str(y[i])
        xmax = xm.SubElement(bndbox,"xmax")
        xmax.text = str(x[i]+w[i])
        ymax = xm.SubElement(bndbox,"ymax")
        ymax.text = str(y[i]+h[i])
        
    tree = xm.ElementTree(annotation)
    with open(os.path.join(path,filename+'.xml'),"wb") as files:
        tree.write(files)

# %%
for filename,group in df.groupby('filename'):
    x = []
    y = []
    w = []
    h = []
    count=0
    for row_index,row in group.iterrows():
        count+=1
        x.append(row['x'])
        y.append(row['y'])
        w.append(row['w'])
        h.append(row['h'])
    GenerateXML(filename[:-4],count,x,y,w,h)
